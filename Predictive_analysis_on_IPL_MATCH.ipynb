# %% [markdown]
# <a href="https://colab.research.google.com/github/1PD-IS-NO-1/mlproject/blob/main/Predictive_analysis_on_IPL_MATCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/matches - matches.csv')

# %%
df.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.shape
# Out:
# (636, 18)

# %%
df.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.iloc[0]  # Selects the first row
# it will give you give series if you want  only  one row but if you want more then one row then it will give you dataframe
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
df.iloc[0:2]  # Selects the first 5 rows
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
# Selecting columns by name
df.loc[:, ['team1', 'team2', 'winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df['winner'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['winner'].value_counts().head().plot(kind = 'bar')
# Out:
# <Axes: xlabel='winner'>

# %%
df['winner'].value_counts().head().plot(kind = 'pie',autopct='%1.1f%%')
#in this we only 5 top
# Out:
# <Axes: ylabel='count'>

# %%
df['team1'].value_counts() + df['team2'].value_counts()
# so maximum match played by mumbai indians
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %% [markdown]
# # **matplotlib practice for ploting on **

# %%
deliveri = pd.read_csv('/content/deliveries.csv.zip')

# %%
deliveri.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
from re import T
combine = deliveri.merge(df,left_on = 'match_id',right_on='id')

# %%
combine.sample(2)
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 10764         46       2                Gujarat Lions      Kings XI Punjab
# 127750       538       2  Royal Challengers Bangalore  Chennai Super Kings
#
#         over  ball   batsman     non_striker     bowler  is_super_over  ...  \
# 10764      4     1  DR Smith    Ishan Kishan   VR Aaron              0  ...
# 127750    11     1   V Kohli  AB de Villiers  IC Pandey              0  ...
#
#         result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 10764   normal           0        Gujarat Lions            0               6
# 127750  normal           0  Chennai Super Kings           27               0
#
#         player_of_match                                              venue  \
# 10764          DR Smith  Punjab Cricket Association IS Bindra Stadium, ...
# 127750         SK Raina                              M Chinnaswamy Stadium
#
# ...

# %%
combine.shape
# Out:
# (150460, 39)

# %%
import seaborn as sns

# %%
combine.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
new_combine = combine[(combine['batsman'] == 'V Kohli') | (combine['batsman'] == 'RG Sharma')]

# %%
Season = new_combine.groupby(['season','batsman'])

# %%
new_combine.head()
# Out:
#      match_id  inning    batting_team            bowling_team  over  ball  \
# 275         2       1  Mumbai Indians  Rising Pune Supergiant     5     3
# 276         2       1  Mumbai Indians  Rising Pune Supergiant     5     4
# 278         2       1  Mumbai Indians  Rising Pune Supergiant     5     6
# 279         2       1  Mumbai Indians  Rising Pune Supergiant     6     1
# 285         2       1  Mumbai Indians  Rising Pune Supergiant     7     1
#
#        batsman non_striker       bowler  is_super_over  ...  result  \
# 275  RG Sharma  JC Buttler  Imran Tahir              0  ...  normal
# 276  RG Sharma  JC Buttler  Imran Tahir              0  ...  normal
# 278  RG Sharma  JC Buttler  Imran Tahir              0  ...  normal
# 279  RG Sharma  JC Buttler    DL Chahar              0  ...  normal
# 285  RG Sharma  JC Buttler  Imran Tahir              0  ...  normal
#
#      dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
Season

# %%
Season.count()
# Out:
#                   match_id  inning  batting_team  bowling_team  over  ball  \
# season batsman
# 2008   RG Sharma       276     276           276           276   276   276
#        V Kohli         168     168           168           168   168   168
# 2009   RG Sharma       323     323           323           323   323   323
#        V Kohli         225     225           225           225   225   225
# 2010   RG Sharma       310     310           310           310   310   310
#        V Kohli         216     216           216           216   216   216
# 2011   RG Sharma       304     304           304           304   304   304
#        V Kohli         473     473           473           473   473   473
# 2012   RG Sharma       350     350           350           350   350   350
#        V Kohli         333     333           333           333   333   333
# 2013   RG Sharma       415     415           415           415   415   415
# ...

# %%
Season.sum()
# Out:
#                   match_id  inning  \
# season batsman
# 2008   RG Sharma     24106     388
#        V Kohli       14955     209
# 2009   RG Sharma     47171     467
#        V Kohli       32396     370
# 2010   RG Sharma     64286     480
#        V Kohli       44548     350
# 2011   RG Sharma     82780     389
#        V Kohli      130251     794
# 2012   RG Sharma    120823     584
#        V Kohli      115900     484
# 2013   RG Sharma    174026     566
#        V Kohli      196574     616
# 2014   RG Sharma    149968     405
#        V Kohli      147470     459
# 2015   RG Sharma    184937     441
#        V Kohli      216513     635
# 2016   RG Sharma    223262     658
#        V Kohli      397992     864
# 2017   RG Sharma     10561     444
#        V Kohli        7692     331
#
#                                                        batting_team  \
# season batsman
# 2008   RG Sharma  Deccan ChargersDeccan ChargersDeccan ChargersD...
# ...

# %%
type(Season.sum())
# Out:
# pandas.core.frame.DataFrame

# %%
Season.size()
# Out:
# season  batsman
# 2008    RG Sharma    276
#         V Kohli      168
# 2009    RG Sharma    323
#         V Kohli      225
# 2010    RG Sharma    310
#         V Kohli      216
# 2011    RG Sharma    304
#         V Kohli      473
# 2012    RG Sharma    350
#         V Kohli      333
# 2013    RG Sharma    415
#         V Kohli      471
# 2014    RG Sharma    307
#         V Kohli      301
# 2015    RG Sharma    339
#         V Kohli      395
# 2016    RG Sharma    372
#         V Kohli      655
# 2017    RG Sharma    278
#         V Kohli      257
# dtype: int64

# %%
price = [6,5,4,3,7,8]
year = [2020,2021,2022,2023,2024,2025]

# %%
plt.plot(year,price,color = 'yellow')
plt.title("practice")
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
x = np.linspace(-10,10,50)
y = 10*x +3 + np.random.randint(0,300,50)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %% [markdown]
# # **import batter dataset**

# %%
df2 = pd.read_csv('/content/batter.csv')

# %%
df2 = df2.head(50)

# %%
df2.head(2)
# Out:
#      batter  runs        avg  strike_rate
# 0   V Kohli  6634  36.251366   125.977972
# 1  S Dhawan  6244  34.882682   122.840842

# %%
plt.scatter(df2['avg'], df2['strike_rate'])
# Make sure to use a different variable name for the string value


plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # bar plot batsman_season_record

# %%
df3 =  pd.read_csv('/content/batsman_season_record.csv')

# %%
df3.shape
# Out:
# (5, 4)

# %%
df3.head()
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(np.arange(df3.shape[0]) - 0.2, df3['2015'], width=0.2, color='yellow')
plt.bar(np.arange(df3.shape[0]), df3['2016'], width=0.2, color='orange')
plt.bar(np.arange(df3.shape[0]) + 0.2, df3['2017'], width=0.2, color='blue')
plt.xticks(np.arange(df3.shape[0]), df3['batsman'])
#plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x7df1bcf9d4b0>,
# ...
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])
